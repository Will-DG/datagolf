# %%
win_url = 'https://www.playnow.com/sports?action=GoAjaxEvType&ev_oc_grp_id=389569'
top5_url = 'https://www.playnow.com/sports?action=GoAjaxEvType&ev_oc_grp_id=391235'
top20_url = 'https://www.playnow.com/sports?action=GoAjaxEvType&ev_oc_grp_id=391610'


r = requests.get(win_url)
win = []
for soup in BeautifulSoup(r.content, 'html.parser').find_all('tr'):
    new = {}
    new["Player.Name"] = soup.find('td', {"class":"eventInfoLeft"}).get_text().replace(' \n\n', '')
    new["Win"] = float(soup.find('a', {"class":"price-active control-add-seln marketOdds "}).get_text().replace('\n', '').replace('\t', ''))
    win.append(new)
win = pd.DataFrame(win)

r = requests.get(top5_url)
top5 = []
for soup in BeautifulSoup(r.content, 'html.parser').find_all('tr'):
    new = {}
    new["Player.Name"] = soup.find('td', {"class":"eventInfoLeft"}).get_text().replace(' \n\n', '')
    new["Top5"] = float(soup.find('a', {"class":"price-active control-add-seln marketOdds "}).get_text().replace('\n', '').replace('\t', ''))
    top5.append(new)
top5 = pd.DataFrame(top5)


r = requests.get(top20_url)
top20 = []
for soup in BeautifulSoup(r.content, 'html.parser').find_all('tr'):
    new = {}
    new["Player.Name"] = soup.find('td', {"class":"eventInfoLeft"}).get_text().replace(' \n\n', '')
    new["Top20"] = float(soup.find('a', {"class":"price-active control-add-seln marketOdds "}).get_text().replace('\n', '').replace('\t', ''))
    top20.append(new)
top20 = pd.DataFrame(top20)

first = pd.merge(win, top5, on="Player.Name")
final = pd.merge(first, top20, on="Player.Name")

final["Win"] = 1 / final["Win"]
final["Top5"] = 1 / final["Top5"]
final["Top20"] = 1 / final["Top20"]

# %%
final.loc[final['Player.Name'].str.split().str.len() == 2, 'Player.Name'] = \
            final['Player.Name'].str.split().str[-1] + ', ' + final['Player.Name'].str.split().str[0]
 
final.loc[final['Player.Name'].str.split().str.len() > 2, 'Player.Name'] = \
            final['Player.Name'].str.split().str[1] + ' ' + final['Player.Name'].str.split().str[2] + \
            ', ' + final['Player.Name'].str.split().str[0]

# %%
top20.loc[top20['Player.Name'].str.split().str.len() == 2, 'Player.Name'] = \
            top20['Player.Name'].str.split().str[-1] + ', ' + top20['Player.Name'].str.split().str[0]
 
top20.loc[top20['Player.Name'].str.split().str.len() > 2, 'Player.Name'] = \
            top20['Player.Name'].str.split().str[1] + ' ' + top20['Player.Name'].str.split().str[2] + \
            ', ' + top20['Player.Name'].str.split().str[0]

# %%
first = pd.merge(win, top5, on="Player.Name")

# %%
final = pd.merge(first, top20, on="Player.Name")
final
# Out:
#               Player.Name    Win    Top5  Top20
# 0          Spieth, Jordan   13.0    2.65   1.76
# 1         Johnson, Dustin   15.0    2.55   1.72
# 2          Garcia, Sergio   18.0    2.95   1.85
# 3        Fleetwood, Tommy   22.0    3.35   2.35
# 4             Casey, Paul   30.0    4.40   2.60
# 5          Koepka, Brooks   40.0    4.80   2.85
# 6          Leishman, Marc   45.0    5.70   3.00
# 7       Oosthuizen, Louis   50.0    6.00   3.45
# 8            Kuchar, Matt   55.0    5.70   3.20
# 9         Pieters, Thomas   70.0    6.50   4.00
# 10          Westwood, Lee   70.0    8.00   4.20
# 11           Poulter, Ian   70.0    7.00   3.90
# 12         Thomas, Justin   80.0    7.50   3.30
# 13   Fitzpatrick, Matthew   80.0    8.50   4.40
# 14          Johnson, Zach   80.0    7.50   4.00
# 15           Fisher, Ross   90.0    7.50   3.50
# 16        Kjeldsen, Soren  100.0   12.00   5.70
# 17          Kisner, Kevin  125.0   10.00   4.80
# 18        Hatton, Tyrrell  125.0    8.50   4.80
# 19       Johnston, Andrew  125.0   14.00   7.50
# 20      Wiesberger, Bernd  125.0   11.00   5.70
# 21       Hoffman, Charley  125.0   14.00   5.70
# 22        Henley, Russell  125.0   11.00   5.30
# 23         Woodland, Gary  150.0   15.00   7.00
# 24      Olesen, Thorbjorn  150.0   14.00   7.00
# 25         Uihlein, Peter  150.0   13.00   6.50
# 26              Fox, Ryan  150.0   17.00   7.50
# 27          Walker, Jimmy  175.0   14.00   7.00
# 28          Simpson, Webb  175.0   14.00   6.50
# 29             Els, Ernie  200.0   22.00  10.00
# ..                    ...    ...     ...    ...
# 105         Horsey, David  250.0   30.00  10.00
# 106        Smith, Cameron  250.0   20.00  10.00
# 107       Lovemark, Jamie  250.0   20.00   9.50
# 108        Hamilton, Todd  300.0   70.00  26.00
# 109             Na, Kevin  300.0   20.00   9.50
# 110            Daly, John  300.0   70.00  30.00
# 111        Bland, Richard  300.0   26.00  10.00
# 112      Cianchetti, Luca  300.0   80.00  26.00
# 113       Castro, Roberto  300.0   35.00  15.00
# 114      Vegas, Jhonattan  300.0   40.00  17.00
# 115           Hend, Scott  300.0   26.00  11.00
# 116           Bulle, Kent  300.0   55.00  22.00
# 117      Bjork, Alexander  300.0   20.00   9.50
# 118     Larrazabal, Pablo  300.0   18.00   8.50
# 119           Bland, Adam  300.0   40.00  18.00
# 120           Kapur, Shiv  300.0   30.00  12.00
# 121          Waring, Paul  300.0   26.00  11.00
# 122     Dinwiddie, Robert  300.0   50.00  22.00
# 123        Manley, Stuart  300.0   40.00  17.00
# 124            Tree, Toby  300.0   70.00  26.00
# 125      Fichardt, Darren  300.0   40.00  18.00
# 126        Canter, Laurie  300.0   40.00  18.00
# 127          Syme, Connor  300.0   70.00  30.00
# 128       Drysdale, David  300.0   22.00  10.00
# 129         Lipsky, David  300.0   35.00  16.00
# 130       Song, Young-Han  300.0   35.00  17.00
# 131          Plant, Alfie  300.0  100.00  40.00
# 132       Hodkinson, Adam  300.0  125.00  45.00
# 133        McCarthy, Ryan  300.0   55.00  22.00
# 134          Dodt, Andrew  300.0   22.00  11.00
#
# [135 rows x 4 columns]

# %%
final["Win"] = 1 / final["Win"]
final["Top5"] = 1 / final["Top5"]
final["Top20"] = 1 / final["Top20"]

# %%
final.to_csv('~/Dropbox/Prediction Model/playnow_odds.csv', sep=',', index=False)

# %%
import pandas as pd

data = pd.read_csv('~/Dropbox/Prediction Model/rround.TXT', sep=';')
#data = pd.read_csv('~/Desktop/Tableau Interactive/rround2006.TXT', sep=';')
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (22,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
aug = data[data['Event Name'].str.contains('Masters')]

# %%
aug['Driving Distance(Total Drives)']
# Out:
# 2611    0
# 2612    0
# 2613    0
# 2614    0
# 2615    0
# 2616    0
# 2617    0
# 2618    0
# 2619    0
# 2620    0
# 2621    0
# 2622    0
# 2623    0
# 2624    0
# 2625    0
# 2626    0
# 2627    0
# 2628    0
# 2629    0
# 2630    0
# 2631    0
# 2632    0
# 2633    0
# 2634    0
# 2635    0
# 2636    0
# 2637    0
# 2638    0
# 2639    0
# 2640    0
#        ..
# 2674    0
# 2675    0
# 2676    0
# 2677    0
# 2678    0
# 2679    0
# 2680    0
# 2681    0
# 2682    0
# 2683    0
# 2684    0
# 2685    0
# 2686    0
# 2687    0
# 2688    0
# 2689    0
# 2690    0
# 2691    0
# 2692    0
# 2693    0
# 2694    0
# 2695    0
# 2696    0
# 2697    0
# 2698    0
# 2699    0
# 2700    0
# 2701    0
# 2702    0
# 2703    0
# Name: Driving Distance(Total Drives), dtype: int64

# %%
data = data[['Tournament Year', 'Course #', 'Course Name', 'Course Par', 'Course Yardage', 'Round Score']]
data['Round Score'] = data['Round Score'] - data['Course Par']

means = data.groupby(['Tournament Year', 'Course #', 'Course Name'])[['Course Yardage', 'Round Score']].mean().reset_index()
sd = data.groupby(['Tournament Year', 'Course #', 'Course Name'])[['Round Score']].std().reset_index()

means['score_avg'] = means['Round Score']
sd['std_dev'] = sd['Round Score']
del means['Round Score']
del sd['Round Score']

total = means.merge(sd, on=['Tournament Year', 'Course #', 'Course Name'])

# %%
total
# Out:
#     Tournament Year  Course #                     Course Name  Course Yardage  \
# 0              2006         4         Torrey Pines GC (South)          7568.0
# 1              2006         5                 Pebble Beach GL          6816.0
# 2              2006         6                      Waialae CC          7060.0
# 3              2006         8                 Doral CC (Blue)          7266.0
# 4              2006         9           Bay Hill Club & Lodge          7267.0
# 5              2006        11                    TPC Sawgrass          7098.0
# 6              2006        12                 Harbour Town GL          6973.0
# 7              2006        13                  Forest Oaks CC          7333.0
# 8              2006        14             Augusta National GC          7445.0
# 9              2006        19         TPC Four Seasons Resort          7052.0
# 10             2006        21                     Colonial CC          7054.0
# 11             2006        23            Muirfield Village GC          7337.0
# 12             2006        27                  Westchester CC          6839.0
# 13             2006        35              Warwick Hills G&CC          7127.0
# 14             2006        36            Firestone CC (South)          7360.0
# 15             2006        45                     Magnolia GC          7516.0
# 16             2006        56                 Castle Pines GC          7619.0
# 17             2006       101              Tucson National GC          7193.0
# 18             2006       102                Bermuda Dunes CC          6962.0
# 19             2006       104            Torrey Pines (North)          6874.0
# 20             2006       145                         Palm GC          6957.0
# 21             2006       202                    La Quinta CC          7060.0
# 22             2006       205                Spyglass Hill GC          6862.0
# 23             2006       500                      Riviera CC          7279.0
# 24             2006       502                  Winged Foot GC          7264.0
# 25             2006       503             TPC River Highlands          6820.0
# 26             2006       510                  TPC Scottsdale          7216.0
# 27             2006       511               English Turn G&CC          7078.0
# 28             2006       512                      TPC Avenel          6987.0
# 29             2006       513                   TPC Southwind          7244.0
# 30             2006       526                   Cog Hill G&CC          7326.0
# 31             2006       530                     Poppy Hills          6833.0
# 32             2006       538                   TPC Summerlin          7243.0
# 33             2006       609                    Annandale GC          7199.0
# 34             2006       612              Brown Deer Park GC          6759.0
# 35             2006       613            Cottonwood Valley GC          6871.0
# 36             2006       625           LaCantera GC (Resort)          6881.0
# 37             2006       638                   TPC Sugarloaf          7343.0
# 38             2006       649               PGA West (Palmer)          6930.0
# 39             2006       656    Plantation Course at Kapalua          7411.0
# 40             2006       659              Medinah CC (No. 3)          7561.0
# 41             2006       660                   Montreux G&CC          7472.0
# 42             2006       663         La Costa Resort and Spa          7277.0
# 43             2006       665  Westin Innisbrook (Copperhead)          7340.0
# 44             2006       669                   TPC Deere Run          7193.0
# 45             2006       681                     TPC Canyons          7063.0
# 46             2006       688                    East Lake GC          7154.0
# 47             2006       694                   Hamilton G&CC          6983.0
# 48             2006       696         Nemacolin (Mystic Rock)          7550.0
# 49             2006       698               Quail Hollow Club          7442.0
# 50             2006       700                      TPC Boston          7415.0
# 51             2006       710          CC at Mirasol (Sunset)          7384.0
# 52             2006       723                The Classic Club          7305.0
# 53             2006       724              Royal Liverpool GC          7258.0
# 54             2006       726                       The Grove          7125.0
# 55             2006       729        Redstone GC (Tournament)          7457.0
# 56             2006       730                     Atunyote GC          7315.0
#
#     score_avg   std_dev
# 0    1.689655  2.989645
# 1    0.485830  3.368735
# 2    0.671840  3.093877
# 3   -1.331776  2.928855
# 4    0.224543  3.105766
# 5    1.528736  3.572937
# 6    0.329268  3.112617
# 7   -0.727053  2.931897
# 8    1.945255  3.446174
# 9    0.782051  2.958002
# 10  -0.039788  2.977934
# 11   1.002817  3.355153
# 12   1.250000  3.107590
# 13  -1.651515  2.911900
# 14   1.170968  3.153022
# 15  -1.941781  2.881396
# 16   0.316883  3.174336
# 17  -1.993023  2.726448
# 18  -2.896000  2.819357
# 19  -2.544872  2.801711
# 20  -2.840278  2.772652
# 21  -1.070866  3.094237
# 22   0.005618  3.221568
# 23   0.428571  2.867590
# 24   4.993135  3.215137
# 25   0.563596  3.021591
# 26  -0.656716  2.928332
# 27  -1.230088  3.170705
# 28  -0.469163  3.283200
# 29   2.162222  3.403509
# 30   0.366109  2.975417
# 31   0.301676  3.129876
# 32  -2.165605  2.862888
# 33  -0.097619  3.107846
# 34  -0.774468  2.942264
# 35   0.130719  3.053671
# 36   0.433486  3.210998
# 37  -0.242697  3.127828
# 38  -2.433071  3.218475
# 39   1.892857  3.233711
# 40   0.635556  3.260833
# 41  -1.071429  3.092009
# 42 -72.000000  0.000000
# 43   0.811558  2.814530
# 44  -0.931034  3.049552
# 45  -2.514085  2.842773
# 46   0.759259  2.928654
# 47   0.267391  2.730491
# 48   0.317972  3.208721
# 49   1.377528  3.403289
# 50   1.611465  3.095604
# 51   1.390588  3.497021
# 52  -0.472906  3.186140
# 53   0.366446  3.187770
# 54  -0.619835  2.865610
# 55   0.289979  2.920076
# 56  -1.108642  3.155704

# %%
total
# Out:
#     Tournament Year  Course #                     Course Name  Course Yardage  \
# 0              2005         4         Torrey Pines GC (South)          7568.0
# 1              2005         5                 Pebble Beach GL          6737.0
# 2              2005         6                      Waialae CC          7060.0
# 3              2005         8                 Doral CC (Blue)          7266.0
# 4              2005         9           Bay Hill Club & Lodge          7267.0
# 5              2005        11                    TPC Sawgrass          7093.0
# 6              2005        12                 Harbour Town GL          6973.0
# 7              2005        13                  Forest Oaks CC          7333.0
# 8              2005        14             Augusta National GC          7290.0
# 9              2005        19         TPC Four Seasons Resort          7016.0
# 10             2005        21                     Colonial CC          7054.0
# 11             2005        23            Muirfield Village GC          7300.0
# 12             2005        24         Congressional CC (Blue)          7232.0
# 13             2005        27                  Westchester CC          6839.0
# 14             2005        35              Warwick Hills G&CC          7127.0
# 15             2005        36            Firestone CC (South)          7360.0
# 16             2005        37                      En-Joie GC          6974.0
# 17             2005        45                     Magnolia GC          7516.0
# 18             2005        56                 Castle Pines GC          7619.0
# 19             2005       101              Tucson National GC          7109.0
# 20             2005       102                Bermuda Dunes CC          6962.0
# 21             2005       104            Torrey Pines (North)          6874.0
# 22             2005       145                         Palm GC          6957.0
# 23             2005       202                    La Quinta CC          7060.0
# 24             2005       205                Spyglass Hill GC          6862.0
# 25             2005       302                     Tamarisk CC          7003.0
# 26             2005       500                      Riviera CC          7260.0
# 27             2005       503             TPC River Highlands          6820.0
# 28             2005       510                  TPC Scottsdale          7216.0
# 29             2005       513                   TPC Southwind          7244.0
# 30             2005       526                   Cog Hill G&CC          7326.0
# 31             2005       530                     Poppy Hills          6833.0
# 32             2005       538                   TPC Summerlin          7243.0
# 33             2005       609                    Annandale GC          7199.0
# 34             2005       612              Brown Deer Park GC          6759.0
# 35             2005       613            Cottonwood Valley GC          6861.0
# 36             2005       625           LaCantera GC (Resort)          6881.0
# 37             2005       638                   TPC Sugarloaf          7293.0
# 38             2005       649               PGA West (Palmer)          6930.0
# 39             2005       656    Plantation Course at Kapalua          7263.0
# 40             2005       657        Pinehurst Resort (No. 2)          7214.0
# 41             2005       660                   Montreux G&CC          7472.0
# 42             2005       663         La Costa Resort and Spa          7277.0
# 43             2005       665  Westin Innisbrook (Copperhead)          7340.0
# 44             2005       668  St. Andrews Links (Old Course)          7279.0
# 45             2005       669                   TPC Deere Run          7193.0
# 46             2005       681                     TPC Canyons          7063.0
# 47             2005       688                    East Lake GC          7154.0
# 48             2005       696         Nemacolin (Mystic Rock)          7516.0
# 49             2005       698               Quail Hollow Club          7442.0
# 50             2005       699        Redstone GC (Fall Creek)          7508.0
# 51             2005       700                      TPC Boston          7415.0
# 52             2005       710          CC at Mirasol (Sunset)          7384.0
# 53             2005       714                   TPC Louisiana          7520.0
# 54             2005       715                    Baltusrol GC          7392.0
# 55             2005       716                Shaughnessy G&CC          7010.0
# 56             2005       717                 Harding Park GC          7086.0
#
#     score_avg   std_dev
# 0    1.050955  2.972281
# 1   -0.250000  3.247787
# 2    0.903153  2.974244
# 3   -1.421286  2.768054
# 4    1.243243  3.255226
# 5    0.841410  3.734152
# 6    2.245742  3.266302
# 7   -1.430993  2.831550
# 8    1.975265  4.108815
# 9    0.062092  2.991694
# 10  -0.243243  2.978745
# 11  -0.067935  2.997411
# 12   0.118834  2.907063
# 13   2.033186  3.323137
# 14  -1.558635  2.898437
# 15   1.365248  3.087905
# 16  -2.748201  2.864135
# 17  -2.131944  2.589840
# 18   0.627737  3.088943
# 19  -1.769953  3.028281
# 20  -3.354331  2.694873
# 21  -2.562914  2.634581
# 22  -4.197183  2.750215
# 23  -2.377953  2.681297
# 24   0.134078  2.876466
# 25  -3.346457  2.971766
# 26   0.377622  3.055749
# 27   0.239741  3.203214
# 28   0.572464  3.609688
# 29   1.281938  3.269334
# 30   0.915743  3.205827
# 31  -0.085227  3.051671
# 32  -1.876623  3.245298
# 33  -1.973236  2.646998
# 34  -0.743478  2.767588
# 35  -0.019355  2.829508
# 36  -0.290698  3.059116
# 37   0.818182  3.177720
# 38  -1.468293  3.136630
# 39  -2.774194  2.649862
# 40   4.165966  3.276676
# 41  -0.467822  3.314972
# 42 -72.000000  0.000000
# 43   1.229426  2.848198
# 44   0.672340  3.270186
# 45  -0.883772  3.007989
# 46  -2.825175  2.557273
# 47  -0.586207  2.677016
# 48   0.334118  3.195868
# 49   1.741935  3.320856
# 50   0.301724  3.035342
# 51   0.017204  2.883463
# 52  -0.051919  3.178621
# 53   0.404661  2.842545
# 54   2.453191  3.260041
# 55   2.533040  3.198028
# 56   0.932143  2.957107

# %%
total
# Out:
#     Tournament Year  Course #                     Course Name  Course Yardage  \
# 0              2017         4         Torrey Pines GC (South)          7698.0
# 1              2017         5                 Pebble Beach GL          6816.0
# 2              2017         6                      Waialae CC          7044.0
# 3              2017         9           Bay Hill Club & Lodge          7419.0
# 4              2017        11                    TPC Sawgrass          7189.0
# 5              2017        12                 Harbour Town GL          7099.0
# 6              2017        14             Augusta National GC          7435.0
# 7              2017        19         TPC Four Seasons Resort          7166.0
# 8              2017        21                     Colonial CC          7209.0
# 9              2017        23            Muirfield Village GC          7392.0
# 10             2017       104            Torrey Pines (North)          7258.0
# 11             2017       185             Austin Country Club          7108.0
# 12             2017       202                    La Quinta CC          7060.0
# 13             2017       205                Spyglass Hill GC          6953.0
# 14             2017       231  Sea Island Resort (Plantation)          7058.0
# 15             2017       233      Nicklaus Tournament Course          7159.0
# 16             2017       235           Eagle Point Golf Club          7396.0
# 17             2017       236                      Erin Hills          7741.0
# 18             2017       237      TPC Potomac at Avenel Farm          7107.0
# 19             2017       240        Club de Golf Chapultepec          7330.0
# 20             2017       500                      Riviera CC          7322.0
# 21             2017       503             TPC River Highlands          6841.0
# 22             2017       510                  TPC Scottsdale          7266.0
# 23             2017       513                   TPC Southwind          7244.0
# 24             2017       538                   TPC Summerlin          7255.0
# 25             2017       552  Silverado Resort and Spa North          7166.0
# 26             2017       656    Plantation Course at Kapalua          7452.0
# 27             2017       665  Innisbrook Resort (Copperhead)          7340.0
# 28             2017       704                  Stadium Course          7113.0
# 29             2017       714                   TPC Louisiana          7425.0
# 30             2017       729                   GC of Houston          7441.0
# 31             2017       733                  El Camaleon GC          6987.0
# 32             2017       734         PGA National (Champion)          7140.0
# 33             2017       742            Coco Beach Golf & CC          7506.0
# 34             2017       746                   CC of Jackson          7421.0
# 35             2017       766        Sheshan International GC          7261.0
# 36             2017       769           Monterey Peninsula CC          6958.0
# 37             2017       770     TPC San Antonio - AT&T Oaks          7435.0
# 38             2017       771               The Old White TPC          7286.0
# 39             2017       776     Sea Island Resort (Seaside)          7005.0
# 40             2017       800                TPC Kuala Lumpur          7005.0
#
#     score_avg    std_dev
# 0    0.766234   3.271219
# 1   -0.100000   3.089088
# 2   -1.690745   2.642599
# 3    0.890052   3.226930
# 4    1.290909   3.072682
# 5   -0.323601   2.780578
# 6    1.886986   3.308466
# 7    0.817391   3.156299
# 8    1.154047   3.016495
# 9    0.797436   3.294850
# 10  -0.722581   2.297756
# 11 -21.178571  25.185487
# 12  -2.365385   2.639860
# 13   0.202614   2.907249
# 14  -2.237179   3.096537
# 15  -1.256410   2.859894
# 16   0.824295   2.829491
# 17   1.203579   3.317461
# 18   1.458115   3.184126
# 19   0.049342   3.128839
# 20   0.011792   3.043786
# 21   0.198718   3.064097
# 22  -0.808252   2.955407
# 23   0.629550   3.037290
# 24  -1.376744   2.952210
# 25  -1.172897   2.874912
# 26  -2.625000   2.310537
# 27   0.511792   2.896130
# 28  -0.412017   2.742110
# 29 -12.588235  14.162166
# 30  -0.018307   3.209023
# 31  -1.391089   3.039120
# 32   0.555819   2.966455
# 33  -1.768675   2.725702
# 34  -0.942308   2.961038
# 35  -0.096154   3.457187
# 36   0.259740   3.069575
# 37   0.852814   3.138174
# 38  -0.138767   2.796346
# 39  -1.111111   2.918692
# 40  -1.701923   2.972153
